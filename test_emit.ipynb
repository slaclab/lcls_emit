# %%
from emittance_calc import *
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-6f4783eebbbb> in <module>
# ----> 1 from emittance_calc import *
#       2 import matplotlib.pyplot as plt
#
# ~/Documents/SLAC/lcls_emit/emittance_calc.py in <module>
#       9 #from beam_io_sim import get_sizes
#      10 # on lcls
# ---> 11 from beam_io import get_beamsizes, setquad
#      12 get_sizes = get_beamsizes
#      13 import json
#
# ~/Documents/SLAC/lcls_emit/beam_io.py in <module>
#       7 import matplotlib.pyplot as plt
#       8
# ----> 9 from image import Image
#      10 from os.path import exists
#      11
#
# ~/Documents/SLAC/lcls_emit/image.py in <module>
#       5 from scipy.optimize import curve_fit
#       6
# ----> 7 from fitting_methods import *
#       8
#       9 class Image:
#
# ~/Documents/SLAC/lcls_emit/fitting_methods.py in <module>
#      11
# ...

# %%
# !pwd
# Out:
# /Users/edelen/NEW/FACET/facet_edelen/edelen/Untitled Folder/lcls_emit

# %% [markdown]
# ## Testing emit fn

# %%
quad_list = [-7.75, -7.25, -6.75, -6.25,  -5.75] 
xrms = [300*10**-6, 300*10**-6, 6.55396626e-05,201*100*-6, 7.99284069e-05]
yrms =[250*10**-6, 180*10**-6, 125*10**-6, 200*10**-6, 300*10**-6]
xrms_err = np.array([0, 0, 0,0,0,0])
yrms_err = np.array([0, 0, 0,0,0,0])
energy =0.120
emittance = get_normemit(energy, quad_list, quad_list, yrms, yrms, adapt_ranges=False, num_points=len(quad_list), show_plots=True)
# Out:
# False
# nemitx: 4.22, nemity: 4.22
# nemitx_err: 0.40, nemity_err: 0.40
# bmagx: 1.03, bmagy: 1.09
# bmagx_err: 0.15, bmagy_err: 0.16

# %%
quad_list = [-5.38210006, -4.24154984, -3.71824052, -3.17573903, -1.99949716] 
xrms = [1.59568569e-04, 8.75908038e-05, 6.55396626e-05, 4.85704395e-05, 7.99284069e-05]
yrms =[9.65669677e-05, 5.61440470e-05, 4.89721770e-05, 4.80127438e-05, 5.86293035e-05]
xrms_err = np.array([0, 0, 0,0,0,0])
yrms_err = np.array([0, 0, 0,0,0,0])
energy =0.135
emittance = get_normemit(energy, quad_list, quad_list, xrms, yrms, adapt_ranges=False, num_points=len(quad_list), show_plots=True)
# Out:
# foo False
# False
# nemitx: 0.48, nemity: 0.26
# nemitx_err: 0.05, nemity_err: 0.03
# bmagx: 1.08, bmagy: 1.18
# bmagx_err: 0.09, bmagy_err: 0.28

# %%
quad_list = [-5.38210006, -4.24154984, -3.71824052, -3.17573903, -1.99949716] 
xrms = [1.59568569e-04, 8.75908038e-05, 6.55396626e-05, 4.85704395e-05, 7.99284069e-05]
yrms =[9.65669677e-05, 5.61440470e-05, 4.89721770e-05, 4.80127438e-05, 5.86293035e-05]
xrms_err = np.array([0, 0, 0,0,0,0])
yrms_err = np.array([0, 0, 0,0,0,0])
energy =0.120
emittance = get_normemit(energy, quad_list, quad_list, xrms, yrms, adapt_ranges=False, num_points=len(quad_list), show_plots=True)
# Out:
# nemitx: 0.38, nemity: 0.21
# nemitx_err: 0.04, nemity_err: 0.02
# bmagx: 1.12, bmagy: 1.24
# bmagx_err: 0.09, bmagy_err: 0.30

# %%
adapt_range(quad_list, np.array(xrms),'x', fit_coefs=None,num_points=5, save_plot=False, show_plots=True)
# Out:
# array([-3.72435784, -3.37684908, -3.02934031, -2.68183155, -2.33432278])

# %%
adapt_range(quad_list, np.array(yrms),'y', fit_coefs=None,num_points=5, save_plot=False, show_plots=True)
# Out:
# array([-4.2475211 , -3.67825257, -3.10898404, -2.53971551, -1.97044697])

# %%
# check impact of energy

# %%
quad = [-5.38210006, -4.24154984, -3.71824052, -3.17573903, -1.99949716] 
xrms = [1.59568569e-04, 8.75908038e-05, 6.55396626e-05, 4.85704395e-05, 7.99284069e-05]
yrms = [9.65669677e-05, 5.61440470e-05, 4.89721770e-05, 4.80127438e-05, 5.86293035e-05]

# %%
get_normemit(0.125, quad, quad, xrms, yrms, adapt_ranges=False, num_points=5, show_plots=True)
# Out:
# nemitx: 0.58, nemity: 0.32
# nemitx_err: 0.04, nemity_err: 0.03
# bmagx: 7.85, bmagy: 1.91
# bmagx_err: 0.63, bmagy_err: 0.46
# (5.836857675484277e-07,
#  3.224307948342666e-07,
#  7.850286084759783,
#  1.9148127557577177,
#  4.0318743321521246e-08,
#  2.5628119049172365e-08,
#  0.6318915974010962,
#  0.4598289778272322)
