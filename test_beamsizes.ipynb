# %%
from beam_io import *
# Out:
# did not import epics

# %%
resolution
# Out:
# 1.223e-05

# %%
img = np.load('./saved_images/MD_20211006/img_10-06_23-04-22.npy')
ncol = np.load('./saved_images/MD_20211006/ncol_10-06_23-04-22.npy')
nrow = np.load('./saved_images/MD_20211006/nrow_10-06_23-04-22.npy')

post1 = [img,ncol,nrow]
img = np.load('./saved_images/MD_20211006/img_10-06_23-02-41.npy')
ncol = np.load('./saved_images/MD_20211006/ncol_10-06_23-02-41.npy')
nrow = np.load('./saved_images/MD_20211006/nrow_10-06_23-02-41.npy')
post2 = [img,ncol,nrow]

# %%
post = [post1,post2]

# %%
a = getbeamsizes_from_img(post = post)
# Out:
# 0
# 1

# %%
a[0]*resolution
# Out:
# 8.826163689143492e-05

# %%
a = get_beamsizes(use_profMon=False, reject_bad_beam=True, save_summary = False, post = post)
# Out:
# 0
# 1
# [7.216814136666796, 6.46621206276912, 0.08154101694053217, 0.052713439885817386, 13947.979391009669, 15844.912089201092, array([[ 5.5, 10.5,  8. , ...,  9. ,  9. , 10.5],
#        [ 8.5,  6.5,  9.5, ..., 11.5,  6.5,  8.5],
#        [ 4. , 10.5,  7. , ..., 11.5,  6. , 19. ],
#        ...,
#        [ 9.5,  8.5,  7. , ...,  7. ,  6.5, 20. ],
#        [ 7. ,  5. ,  4.5, ...,  6.5,  9. , 11.5],
#        [10. ,  2.5, 12.5, ...,  0.5,  5. , 12. ]])]

# %%
a
# Out:
# (8.826163689143492e-05,
#  7.908177352766634e-05,
#  9.972466371827084e-07,
#  6.446853698035466e-07)

# %%
a
# Out:
# [6.297613115308507,
#  6.777278821657691,
#  0.5355397278649925,
#  0.5814104832196585,
#  16329.051084122344,
#  15997.122679597076,
#  array([[ 9, 14, 12, ...,  9,  6, 12],
#         [ 9,  5, 10, ...,  9,  0,  8],
#         [ 4, 14,  9, ..., 13, 10, 21],
#         ...,
#         [10,  3,  8, ...,  6,  7, 21],
#         [ 9,  8,  2, ...,  7, 10, 15],
#         [ 9,  0, 12, ...,  0,  6, 12]], dtype=int32)]

# %%
im = np.load('./saved_images/img_2021-11-21_14-16-17-514991.npy')

# %%
im
# Out:
# array([ 9, 14, 12, ...,  0,  6, 12], dtype=int32)

# %%
plt.imshow(im.reshape(ncol,nrow))

# %%
post = [post1,post2]

# %%
post[1]
# Out:
# [array([ 2,  7,  4, ...,  1,  4, 12], dtype=int32), array(270), array(334)]

# %%
plt.imshow(np.mean((post[0][0],post[1][0]),axis=0).reshape(ncol,nrow))

# %%
plt.imshow(img.reshape(ncol,nrow))

# %%
im = Image(img, ncol, nrow, bg_image = bg_image)

im.reshape_im()


plt.imshow(im.proc_image)

# %%
# Out:
# 0
# 1

# %%
np.array(a[0:5])
# Out:
# array([6.29761312e+00, 6.77727882e+00, 5.35539728e-01, 5.81410483e-01,
#        1.63290511e+04])

# %%
getbeamsizes_from_img(num_images = 2, avg = False, subtract_bg = False, post = post)
# Out:
# 0
# 1
# (6.297613115308507,
#  6.777278821657691,
#  0.5355397278649925,
#  0.5814104832196585,
#  16329.051084122344,
#  15997.122679597076)

# %%
 xrms, yrms, xrms_err, yrms_err, xamp, yamp, im = get_beam_image(subtract_bg, post[0])

# %%
xrms
# Out:
# 7.054980661644776

# %%
beamsizes
# Out:
# (7.054980661644776,
#  7.599517412332827,
#  0.10829174240451254,
#  0.1210949101359921,
#  9999.647707916067,
#  9401.945757241545)
